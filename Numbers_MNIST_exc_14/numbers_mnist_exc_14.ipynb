# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Reshape, Flatten, Lambda, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# для использования в сверточной нейронной сети (CNN) изображения должны быть представлены в виде четырехмерного тензора: (число образцов, высота, ширина, число каналов).

train_x = to_categorical(x_train)
train_y = to_categorical(y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[72], line 3
#       1 # для использования в сверточной нейронной сети (CNN) изображения должны быть представлены в виде четырехмерного тензора: (число образцов, высота, ширина, число каналов).
# ----> 3 train_x = to_categorical(x_train)
#       4 train_y = to_categorical(y_train)
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\numerical_utils.py:88, in to_categorical(x, num_classes)
#      86     num_classes = np.max(x) + 1
#      87 batch_size = x.shape[0]
# ---> 88 categorical = np.zeros((batch_size, num_classes))
#      89 categorical[np.arange(batch_size), x] = 1
#      90 output_shape = input_shape + (num_classes,)
#
# MemoryError: Unable to allocate 89.7 GiB for an array with shape (47040000, 256) and data type float64

# %%
model = Sequential([
    Input(shape=(28, 28, 1)),
    Lambda(lambda x: tf.cast(x, dtype=tf.float32) / 255.0), # Нормализация данных
    Conv2D(32, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    Flatten(),
    Dense(64, activation="relu"),
    Dense(10, activation="softmax")
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 model = Sequential([
#       2     Input(shape=(28, 28)),
#       3     Conv2D(32, (3, 3), activation="relu"),
#       4     MaxPooling2D((2, 2)),
#       5     Conv2D(64, (3, 3), activation="relu"),
#       6     MaxPooling2D((2, 2)),
#       7     Conv2D(64, (3, 3), activation="relu"),
#       8     Flatten(),
#       9     Dense(64, activation="relu"),
#      10     Dense(10, activation="softmax")
#      11 ])
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\sequential.py:74, in Sequential.__init__(self, layers, trainable, name)
#      72 for layer in layers:
#      73     self.add(layer, rebuild=False)
# ---> 74 self._maybe_rebuild()
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\sequential.py:139, in Sequential._maybe_rebuild(self)
#     137 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     138     input_shape = self._layers[0].batch_shape
# --> 139     self.build(input_shape)
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\layer.py:223, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     220 @wraps(original_build_method)
#     221 def build_wrapper(*args, **kwargs):
#     222     with obj._open_name_scope():
# --> 223         original_build_method(*args, **kwargs)
#     224     # Record build config.
#     225     signature = inspect.signature(original_build_method)
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\sequential.py:183, in Sequential.build(self, input_shape)
#     181 for layer in self._layers[1:]:
#     182     try:
# --> 183         x = layer(x)
#     184     except NotImplementedError:
#     185         # Can happen if shape inference is not implemented.
#     186         # TODO: consider reverting inbound nodes on layers processed.
#     187         return
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\input_spec.py:202, in assert_input_compatibility(input_spec, inputs, layer_name)
#     200 if spec.min_ndim is not None:
#     201     if ndim is not None and ndim < spec.min_ndim:
# --> 202         raise ValueError(
#     203             f'Input {input_index} of layer "{layer_name}" '
#     204             "is incompatible with the layer: "
#     205             f"expected min_ndim={spec.min_ndim}, "
#     206             f"found ndim={ndim}. "
#     207             f"Full shape received: {shape}"
#     208         )
#     209 # Check dtype.
#     210 if spec.dtype is not None:
#
# ValueError: Input 0 of layer "conv2d_15" is incompatible with the layer: expected min_ndim=4, found ndim=3. Full shape received: (None, 28, 28)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 model.fit(x_train, y_train, epochs=50)
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\nn.py:547, in categorical_crossentropy(target, output, from_logits, axis)
#     541     raise ValueError(
#     542         "Arguments `target` and `output` must be at least rank 1. "
#     543         "Received: "
#     544         f"target.shape={target.shape}, output.shape={output.shape}"
#     545     )
#     546 if len(target.shape) != len(output.shape):
# --> 547     raise ValueError(
#     548         "Arguments `target` and `output` must have the same rank "
#     549         "(ndim). Received: "
#     550         f"target.shape={target.shape}, output.shape={output.shape}"
#     551     )
#     552 for e1, e2 in zip(target.shape, output.shape):
#     553     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(32,), output.shape=(32, 10)
