# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model # шаблон линейной модели.

# %%
df = pd.read_excel("price1.xlsx")
df
# Out:
#    area  price
# 0    28    3.1
# 1    42    3.8
# 2    45    3.9
# 3    52    4.4
# 4    56    4.5
# 5    68    5.9
# 6    70    5.6
# 7    75    6.4
# 8    90    7.3

# %%
plt.scatter(df.area, df.price, color="red", marker="*")
plt.ylabel("PRICE mln")
plt.xlabel("AREA m²")
plt.plot(df.area, reg.predict(df[["area"]]))

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[["area"]], df[["price"]])
# Out:
# LinearRegression()

# %%
print(f"Коэффициент: {reg.coef_[0]}")
print(f"Перехват: {reg.intercept_}")
# Out:
# Коэффициент: [0.07148238]
# Перехват: [0.8111407]

# %%
reg.predict([[120]])
# Out:
# c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[9.38902671]])

# %%
pred = pd.read_excel("prediction_price.xlsx")
pred
# Out:
#     area
# 0     25
# 1     37
# 2     40
# 3     58
# 4     61
# 5     67
# 6     72
# 7     85
# 8     96
# 9    105
# 10   118

# %%
s = reg.predict(pred)

# %%
pred["predicted prices"] = s
pred
# Out:
#     area  predicted prices
# 0     25          2.598200
# 1     37          3.455989
# 2     40          3.670436
# 3     58          4.957119
# 4     61          5.171566
# 5     67          5.600460
# 6     72          5.957872
# 7     85          6.887143
# 8     96          7.673450
# 9    105          8.316791
# 10   118          9.246062
