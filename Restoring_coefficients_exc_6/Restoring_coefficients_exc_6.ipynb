# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Lambda, Layer

# %%
df = pd.read_csv("data.csv", names=['x', 'f(x)'])
df
# Out:
#             x        f(x)
# 0    9.481538  394.853787
# 1    6.878546  238.295702
# 2    9.436524  393.053669
# 3    3.572694   55.666155
# 4    1.079596   13.537515
# ..        ...         ...
# 995  8.714093  366.701156
# 996  3.783151   60.254649
# 997  9.104563  380.503300
# 998  1.717459   32.758233
# 999  7.288236  277.359814
#
# [1000 rows x 2 columns]

# %%
X = df["x"].values.astype(np.float32)
Y = df["f(x)"].values.astype(np.float32)

check_X = df["x"].isnull().sum() # проверяем есть ли пропущенные строки
check_Y = df["f(x)"].isnull().sum()

# %%
class CustomLayer(Layer):
    def __init__(self, **kwargs):
        super(CustomLayer, self).__init__(**kwargs)
        self.a = self.add_weight(name='a', shape=(), initializer='ones')
        self.b = self.add_weight(name='b', shape=(), initializer='ones')
        self.c = self.add_weight(name='c', shape=(), initializer='ones')

    def call(self, inputs):
        x = inputs
        term1 = self.a * tf.sin(x)
        term2 = self.b * tf.math.log(x)
        term3 = (term1 + term2) ** 2
        term4 = self.c * x ** 2
        return term3 + term4

# %%
input_layer = Input(shape=(1,))
output_layer = CustomLayer()(input_layer)
model = Model(inputs=input_layer, outputs=output_layer)

# %%
model.compile(optimizer="adam", loss="mse")

# %%
model.fit(X, Y, epochs=1000)
# Out:
# Epoch 1/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 23975.9727
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 21559.4375
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 21885.5137
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 22934.6973
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 23084.1387
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 21541.3047
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 21246.3594
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 21148.8164
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 19240.9316
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 19645.6777
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 19358.2832
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17812.7324
# Epoch 13/1000
# ...

# %%
model.get_weights()
# Out:
# [3.1405983, 2.71837, 3.999823]
