# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Lambda
from tensorflow.keras.utils import to_categorical

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# %%
def vectorize_sequences(sequences, dimension=10000):
    result = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        result[i, sequence] = 1
    return result

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)
# ТО ЖЕ САМОЕ - ПРОСТО ТЕПЕРЬ МЕНЯЕТСЯ ФУНКЦИЯ ПОТЕРЬ В model.compile
# y_train = np.array(train_labels)
# y_test = np.array(test_labels)

# %%
model = Sequential([
    Input(shape=(10000,)),
    Dense(64, activation="relu"),
    Dense(46, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
model.fit(x_train, y_train, epochs=20, batch_size=512)
# Out:
# Epoch 1/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4727 - loss: 3.1132
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6926 - loss: 1.7045
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7576 - loss: 1.2267
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8066 - loss: 0.9427
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8327 - loss: 0.7961
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8648 - loss: 0.6714
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8921 - loss: 0.5473
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9073 - loss: 0.4755
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9128 - loss: 0.4311
# Epoch 10/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9256 - loss: 0.3591
# Epoch 11/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9344 - loss: 0.3167
# Epoch 12/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9397 - loss: 0.2849
# Epoch 13/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9392 - loss: 0.2578
# Epoch 14/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9408 - loss: 0.2443
# Epoch 15/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9538 - loss: 0.2075
# Epoch 16/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9516 - loss: 0.1944
# Epoch 17/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9526 - loss: 0.1772
# Epoch 18/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9562 - loss: 0.1685
# Epoch 19/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9570 - loss: 0.1603
# Epoch 20/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9545 - loss: 0.1508

# %%
result = model.evaluate(x_test, y_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.8190 - loss: 0.8467

# %%
pred = model.predict(x_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[1.87485020e-05, 3.97797448e-05, 1.35107564e-06, ...,
#         3.26027271e-06, 1.33102378e-06, 2.30061892e-06],
#        [9.43940366e-04, 1.07199155e-01, 1.31547262e-04, ...,
#         8.68724044e-07, 2.40676331e-06, 6.10306342e-05],
#        [3.26201925e-03, 9.71653163e-01, 2.88114592e-04, ...,
#         7.77269815e-05, 1.33579679e-05, 9.18950027e-05],
#        ...,
#        [1.21643507e-05, 6.73850533e-04, 1.70598596e-05, ...,
#         2.26902903e-05, 9.43265877e-06, 1.69836439e-05],
#        [7.36552989e-04, 3.56192887e-02, 1.18603441e-03, ...,
#         3.34402575e-04, 8.27019976e-05, 2.16264190e-04],
#        [6.22207066e-04, 4.87214565e-01, 2.97359983e-03, ...,
#         9.90992878e-04, 3.95554525e-05, 5.40031178e-05]], dtype=float32)
