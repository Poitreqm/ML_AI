# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten, Normalization
from tensorflow.keras.utils import to_categorical
from ucimlrepo import fetch_ucirepo
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
wine = fetch_ucirepo(id=109) 

X = wine.data.features.values
y = wine.data.targets.values

# %%
label_encoder = LabelEncoder()

y_encode = label_encoder.fit_transform(y) # преобразовывем метки из 1 2
# Out:
# c:\Users\ivanz\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y_encode, test_size=0.3, random_state=42)

# %%
len(x_test)
# Out:
# 54

# %%
normalizer = Normalization() # нормализациционный слой
normalizer.adapt(x_train)

# %%
model = Sequential([
    Input(shape=(13,)),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(3, activation="softmax")
])

# %%
model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',  # потому что y_train это целочисленные метки классов
              metrics=['acc'])

# %%
model.fit(x_train, y_train, epochs=500, validation_data=(x_test, y_test))
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - acc: 0.5287 - loss: 31.7541 - val_acc: 0.3889 - val_loss: 42.3923
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.4400 - loss: 24.2080 - val_acc: 0.3519 - val_loss: 8.9721
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.4430 - loss: 9.7687 - val_acc: 0.3519 - val_loss: 11.6899
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.3303 - loss: 13.1325 - val_acc: 0.3704 - val_loss: 3.7409
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3858 - loss: 6.9118 - val_acc: 0.5000 - val_loss: 1.2772
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3513 - loss: 5.2808 - val_acc: 0.5370 - val_loss: 8.5109
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3540 - loss: 10.9652 - val_acc: 0.6481 - val_loss: 6.0701
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.4834 - loss: 7.2451 - val_acc: 0.5000 - val_loss: 5.6229
# Epoch 9/500
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9545 - loss: 0.1260
# [0.10452441871166229, 0.9629629850387573]

# %%
pred = model.predict(x_train)
pred
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# array([[1.20108226e-08, 2.33096289e-04, 9.99766886e-01],
#        [2.43275223e-04, 9.99706805e-01, 4.99344205e-05],
#        [1.07150016e-04, 9.99767840e-01, 1.24960847e-04],
#        [4.04960096e-01, 5.90455472e-01, 4.58444655e-03],
#        [5.13807720e-07, 9.99990463e-01, 8.98973849e-06],
#        [9.99718845e-01, 2.81146466e-04, 1.16722498e-09],
#        [7.19478782e-11, 3.76584176e-05, 9.99962330e-01],
#        [1.30868580e-06, 9.99997735e-01, 9.98745236e-07],
#        [2.06926146e-07, 9.99994874e-01, 4.96883877e-06],
#        [1.01937188e-10, 9.08820219e-09, 1.00000000e+00],
#        [1.00000000e+00, 6.85905943e-10, 8.44855734e-14],
#        [1.00000000e+00, 1.07508717e-10, 5.81464528e-15],
#        [1.00000000e+00, 5.70937742e-10, 1.93334728e-14],
#        [6.38940989e-08, 6.39572988e-07, 9.99999285e-01],
#        [3.18419334e-05, 9.99542594e-01, 4.25601727e-04],
#        [9.80590582e-01, 1.94070302e-02, 2.46770924e-06],
# ...

# %%
pred_class = np.argmax(pred, axis=1)
pd.DataFrame(pred_class).value_counts() * 100 / len(pred_class)
# Out:
# 0
# 1    49.193548
# 2    27.419355
# 0    23.387097
# Name: count, dtype: float64

# %%
pd.DataFrame(y).value_counts() * 100 / len(y)
# Out:
# 0
# 2    39.887640
# 1    33.146067
# 3    26.966292
# Name: count, dtype: float64
